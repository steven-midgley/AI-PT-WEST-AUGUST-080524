# %%
# Import our dependencies
import pandas as pd
import sklearn as skl
import tensorflow as tf
import matplotlib.pyplot as plt

# Import the nonlinear dummy data
df_circles = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m18/lesson_2/datasets/circles-data.csv")

# Split data into X and y
X = df_circles.drop("Target", axis=1)
y = df_circles["Target"]

# Use sklearn to split dataset
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
df_circles
# Out:
#      Feature 1  Feature 2  Target
# 0    -0.134168   1.023486       0
# 1    -0.279758  -0.726811       1
# 2     0.810913  -0.470461       0
# 3    -0.875263   0.552636       0
# 4     0.421407  -0.714531       1
# ..         ...        ...     ...
# 995   0.265615   0.950331       0
# 996   0.811072   0.448468       0
# 997   0.413404  -0.637738       1
# 998   1.021571  -0.377016       0
# 999  -0.682491   0.358167       1
#
# [1000 rows x 3 columns]

# %%
# Plot the nonlinear dummy data
df_circles.plot(x='Feature 1', y='Feature 2')
# Out:
# <Axes: xlabel='Feature 1'>

# %%
# Create a method that creates a new Sequential model with hyperparameter options


    # Allow kerastuner to decide which activation function to use in hidden layers


    # Allow kerastuner to decide number of neurons in first layer


    # Allow kerastuner to decide number of hidden layers and neurons in hidden layers


    # Compile the model

# %%
# Import the kerastuner library

# %%
# Run the kerastuner search for best hyperparameters
# Out:
# Trial 60 Complete [00h 00m 05s]
# val_accuracy: 0.9520000219345093
#
# Best val_accuracy So Far: 0.9520000219345093
# Total elapsed time: 00h 03m 16s

# %%
# Get top 3 model hyperparameters and print the values
# Out:
# {'activation': 'relu', 'first_units': 21, 'num_layers': 4, 'units_0': 11, 'units_1': 6, 'units_2': 16, 'units_3': 11, 'units_4': 16, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# {'activation': 'tanh', 'first_units': 21, 'num_layers': 4, 'units_0': 26, 'units_1': 26, 'units_2': 26, 'units_3': 11, 'units_4': 26, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}
# {'activation': 'relu', 'first_units': 16, 'num_layers': 4, 'units_0': 1, 'units_1': 11, 'units_2': 6, 'units_3': 16, 'units_4': 16, 'tuner/epochs': 20, 'tuner/initial_epoch': 0, 'tuner/bracket': 0, 'tuner/round': 0}

# %%
# Evaluate the top 3 models against the test dataset
# Out:
# 8/8 - 0s - loss: 0.2370 - accuracy: 0.9520 - 272ms/epoch - 34ms/step
# Loss: 0.2369777262210846, Accuracy: 0.9520000219345093
# 8/8 - 0s - loss: 0.5506 - accuracy: 0.9040 - 307ms/epoch - 38ms/step
# Loss: 0.5505744814872742, Accuracy: 0.9039999842643738
# 8/8 - 0s - loss: 0.5999 - accuracy: 0.7640 - 278ms/epoch - 35ms/step
# Loss: 0.5999231338500977, Accuracy: 0.7639999985694885
